# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
stockprice = pd.read_csv("amazonstock.csv")

# %%
stockprice
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 5918  2020-11-18  3134.000000  3140.000000  3105.100098  3105.459961
# 5919  2020-11-19  3105.310059  3125.000000  3080.919922  3117.020020
# 5920  2020-11-20  3117.020020  3132.889893  3098.050049  3099.399902
# 5921  2020-11-23  3116.699951  3139.750000  3065.459961  3098.389893
# 5922  2020-11-24  3100.500000  3134.250000  3086.260010  3118.060059
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# ...

# %%
stockprice.plot(x="Date", y="Close", figsize=(26,12))
plt.yscale("log")

# %%
stockprice.plot(x="Date", y="Close", figsize=(26,12))
